# %% [markdown]
# <b>LOADING THE DATA<b>

# %%
dataset_year = str(2019)

# %%
from pyspark.sql.functions import *

# %%
# DO NOT CHANGE THE CONTENT OF THIS CELL
import os
import sys

fileroot = "clinicaltrial_" + dataset_year + "_csv"
renamed_fileroot = "clinicaltrial_" + dataset_year + ".csv"
mesh_csv = "/FileStore/tables/mesh.csv"
pharma_csv = "/FileStore/tables/pharma.csv"

# if 'dbruntime.dbutils' in sys.modules.keys():
try:
    dbutils.fs.ls("/FileStore/tables/" + renamed_fileroot)
except:
    dbutils.fs.cp("/FileStore/tables/" + fileroot + ".gz", "file:/tmp/")
    os.environ['fileroot'] = fileroot

# %%
# %sh
gunzip /tmp/ /tmp/$fileroot.gz
# Out:
# gzip: /tmp/ is a directory -- ignored
# gzip: /tmp/clinicaltrial_2019_csv.gz: No such file or directory

# %%
try:
    dbutils.fs.ls("file:/tmp/" + fileroot)
    dbutils.fs.mv("file:/tmp/" + fileroot, "/FileStore/tables/" + renamed_fileroot, True)
except:
    pass

# %%
clinical_csv = "/FileStore/tables/" + renamed_fileroot
mesh_csv = "/FileStore/tables/mesh.csv"
pharma_csv = "/FileStore/tables/pharma.csv"

# %% [markdown]
# NOT SURE YET

# %%
dbutils.fs.ls("/FileStore/tables/")
# Out:
# Out[28]: [FileInfo(path='dbfs:/FileStore/tables/accounts.zip', name='accounts.zip', size=5297592, modificationTime=1645616520000),
#  FileInfo(path='dbfs:/FileStore/tables/clinicaltrial_2019.csv', name='clinicaltrial_2019.csv', size=42400056, modificationTime=1649868197000),
#  FileInfo(path='dbfs:/FileStore/tables/clinicaltrial_2019_csv.gz', name='clinicaltrial_2019_csv.gz', size=10060669, modificationTime=1648766076000),
#  FileInfo(path='dbfs:/FileStore/tables/clinicaltrial_2020.csv', name='clinicaltrial_2020.csv', size=46318151, modificationTime=1648774571000),
#  FileInfo(path='dbfs:/FileStore/tables/clinicaltrial_2020_csv.gz', name='clinicaltrial_2020_csv.gz', size=10981608, modificationTime=1648766091000),
#  FileInfo(path='dbfs:/FileStore/tables/clinicaltrial_2021_csv.gz', name='clinicaltrial_2021_csv.gz', size=11921810, modificationTime=1648766150000),
#  FileInfo(path='dbfs:/FileStore/tables/devicestatus.zip', name='devicestatus.zip', size=23873574, modificationTime=1645364714000),
#  FileInfo(path='dbfs:/FileStore/tables/json_activations.zip', name='json_activations.zip', size=8411369, modificationTime=1645006354000),
#  FileInfo(path='dbfs:/FileStore/tables/letter_frequencies.txt', name='letter_frequencies.txt', size=2593894, modificationTime=1646014004000),
#  FileInfo(path='dbfs:/FileStore/tables/logs.zip', name='logs.zip', size=18168065, modificationTime=1645616573000),
#  FileInfo(path='dbfs:/FileStore/tables/mesh.csv', name='mesh.csv', size=5295548, modificationTime=1648038592000),
#  FileInfo(path='dbfs:/FileStore/tables/pharma.csv', name='pharma.csv', size=678999, modificationTime=1648038593000),
#  FileInfo(path='dbfs:/FileStore/tables/webpage.zip', name='webpage.zip', size=1582, modificationTime=1646215546000)]

# %%
clinicalDF = spark.read.option("header","true").option("inferSchema", "true").option("delimiter", '|').csv(clinical_csv)
meshDF = spark.read.option("header","true").option("inferSchema", "true").csv(mesh_csv)
pharmaDF = spark.read.option("header","true").option("inferSchema", "true").csv(pharma_csv)

# %%
clinicalDF.createOrReplaceTempView("clinicaltrial_view")
meshDF.createOrReplaceTempView("mesh_view")
pharmaDF.createOrReplaceTempView("pharma_view")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
